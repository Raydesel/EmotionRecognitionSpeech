# %%
# %store -r featuresdf_12_test_09
# %store -r featuresdf_12_train_09
# %store -r featuresdf_24_test_09
# %store -r featuresdf_24_train_09
# %store -r featuresdf_36_test_09
# %store -r featuresdf_36_train_09
# %store -r featuresdf_48_test_09
# %store -r featuresdf_48_train_09

# %store -r featuresdf_12_test_010
# %store -r featuresdf_12_train_010
# %store -r featuresdf_24_test_010
# %store -r featuresdf_24_train_010
# %store -r featuresdf_36_test_010
# %store -r featuresdf_36_train_010
# %store -r featuresdf_48_test_010
# %store -r featuresdf_48_train_010

# %store -r featuresdf_12_test_011
# %store -r featuresdf_12_train_011
# %store -r featuresdf_24_test_011
# %store -r featuresdf_24_train_011
# %store -r featuresdf_36_test_011
# %store -r featuresdf_36_train_011
# %store -r featuresdf_48_test_011
# %store -r featuresdf_48_train_011

# %store -r featuresdf_12_test_012
# %store -r featuresdf_12_train_012
# %store -r featuresdf_24_test_012
# %store -r featuresdf_24_train_012
# %store -r featuresdf_36_test_012
# %store -r featuresdf_36_train_012
# %store -r featuresdf_48_test_012
# %store -r featuresdf_48_train_012

# %%
# %store -r featuresdf_10_test_013
# %store -r featuresdf_10_train_013
# %store -r featuresdf_20_test_013
# %store -r featuresdf_20_train_013
# %store -r featuresdf_30_test_013
# %store -r featuresdf_30_train_013
# %store -r featuresdf_40_test_013
# %store -r featuresdf_40_train_013
# %store -r featuresdf_50_test_013
# %store -r featuresdf_50_train_013
# %store -r featuresdf_60_test_013
# %store -r featuresdf_60_train_013
# %store -r featuresdf_70_test_013
# %store -r featuresdf_70_train_013
# %store -r featuresdf_80_test_013
# %store -r featuresdf_80_train_013
# %store -r featuresdf_90_test_013
# %store -r featuresdf_90_train_013
# %store -r featuresdf_100_test_013
# %store -r featuresdf_100_train_013

# %store -r featuresdf_10_test_014
# %store -r featuresdf_10_train_014
# %store -r featuresdf_20_test_014
# %store -r featuresdf_20_train_014
# %store -r featuresdf_30_test_014
# %store -r featuresdf_30_train_014
# %store -r featuresdf_40_test_014
# %store -r featuresdf_40_train_014
# %store -r featuresdf_50_test_014
# %store -r featuresdf_50_train_014
# %store -r featuresdf_60_test_014
# %store -r featuresdf_60_train_014
# %store -r featuresdf_70_test_014
# %store -r featuresdf_70_train_014
# %store -r featuresdf_80_test_014
# %store -r featuresdf_80_train_014
# %store -r featuresdf_90_test_014
# %store -r featuresdf_90_train_014
# %store -r featuresdf_100_test_014
# %store -r featuresdf_100_train_014

# %store -r featuresdf_10_test_015
# %store -r featuresdf_10_train_015
# %store -r featuresdf_20_test_015
# %store -r featuresdf_20_train_015
# %store -r featuresdf_30_test_015
# %store -r featuresdf_30_train_015
# %store -r featuresdf_40_test_015
# %store -r featuresdf_40_train_015
# %store -r featuresdf_50_test_015
# %store -r featuresdf_50_train_015
# %store -r featuresdf_60_test_015
# %store -r featuresdf_60_train_015
# %store -r featuresdf_70_test_015
# %store -r featuresdf_70_train_015
# %store -r featuresdf_80_test_015
# %store -r featuresdf_80_train_015
# %store -r featuresdf_90_test_015
# %store -r featuresdf_90_train_015
# %store -r featuresdf_100_test_015
# %store -r featuresdf_100_train_015

# %store -r featuresdf_10_test_016
# %store -r featuresdf_10_train_016
# %store -r featuresdf_20_test_016
# %store -r featuresdf_20_train_016
# %store -r featuresdf_30_test_016
# %store -r featuresdf_30_train_016
# %store -r featuresdf_40_test_016
# %store -r featuresdf_40_train_016
# %store -r featuresdf_50_test_016
# %store -r featuresdf_50_train_016
# %store -r featuresdf_60_test_016
# %store -r featuresdf_60_train_016
# %store -r featuresdf_70_test_016
# %store -r featuresdf_70_train_016
# %store -r featuresdf_80_test_016
# %store -r featuresdf_80_train_016
# %store -r featuresdf_90_test_016
# %store -r featuresdf_90_train_016
# %store -r featuresdf_100_test_016
# %store -r featuresdf_100_train_016

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
import numpy as np

featuresdf_test_emovo = featuresdf_100_test_016
featuresdf_train_emovo = featuresdf_100_train_016

# %store featuresdf_test_emovo
# %store featuresdf_train_emovo

# Convert features and corresponding classification labels into numpy arrays
x_test = np.array(featuresdf_test_emovo.feature.tolist())
y_test = np.array(featuresdf_test_emovo.class_label.tolist())

le = LabelEncoder()
y_test = to_categorical(le.fit_transform(y_test))

x_train = np.array(featuresdf_train_emovo.feature.tolist())
y_train= np.array(featuresdf_train_emovo.class_label.tolist())

y_train = to_categorical(le.fit_transform(y_train))

# %store x_train 
# %store x_test 
# %store y_train 
# %store y_test 

y_test = np.array(featuresdf_test_emovo.class_label.tolist())

y_train = np.array(featuresdf_train_emovo.class_label.tolist())

y_train = np.append(y_train, y_test)

yy = to_categorical(le.fit_transform(y_train))

# %store yy 
# %store le
# Out:
# Stored 'featuresdf_test_emovo' (DataFrame)
# Stored 'featuresdf_train_emovo' (DataFrame)
# Stored 'x_train' (ndarray)
# Stored 'x_test' (ndarray)
# Stored 'y_train' (ndarray)
# Stored 'y_test' (ndarray)
# Stored 'yy' (ndarray)
# Stored 'le' (LabelEncoder)

# %%
# %store -r featuresdf_EMODB_12_test_09
# %store -r featuresdf_EMODB_12_train_09
# %store -r featuresdf_EMODB_24_test_09
# %store -r featuresdf_EMODB_24_train_09
# %store -r featuresdf_EMODB_36_test_09
# %store -r featuresdf_EMODB_36_train_09
# %store -r featuresdf_EMODB_48_test_09
# %store -r featuresdf_EMODB_48_train_09

# %store -r featuresdf_EMODB_12_test_010
# %store -r featuresdf_EMODB_12_train_010
# %store -r featuresdf_EMODB_24_test_010
# %store -r featuresdf_EMODB_24_train_010
# %store -r featuresdf_EMODB_36_test_010
# %store -r featuresdf_EMODB_36_train_010
# %store -r featuresdf_EMODB_48_test_010
# %store -r featuresdf_EMODB_48_train_010

# %store -r featuresdf_EMODB_12_test_011
# %store -r featuresdf_EMODB_12_train_011
# %store -r featuresdf_EMODB_24_test_011
# %store -r featuresdf_EMODB_24_train_011
# %store -r featuresdf_EMODB_36_test_011
# %store -r featuresdf_EMODB_36_train_011
# %store -r featuresdf_EMODB_48_test_011
# %store -r featuresdf_EMODB_48_train_011

# %store -r featuresdf_EMODB_12_test_012
# %store -r featuresdf_EMODB_12_train_012
# %store -r featuresdf_EMODB_24_test_012
# %store -r featuresdf_EMODB_24_train_012
# %store -r featuresdf_EMODB_36_test_012
# %store -r featuresdf_EMODB_36_train_012
# %store -r featuresdf_EMODB_48_test_012
# %store -r featuresdf_EMODB_48_train_012

# %%
#%store -r featuresdf_EMODB_10_test_013
#%store -r featuresdf_EMODB_10_train_013
# %store -r featuresdf_EMODB_20_test_013
# %store -r featuresdf_EMODB_20_train_013
# %store -r featuresdf_EMODB_30_test_013
# %store -r featuresdf_EMODB_30_train_013
# %store -r featuresdf_EMODB_40_test_013
# %store -r featuresdf_EMODB_40_train_013
# %store -r featuresdf_EMODB_50_test_013
# %store -r featuresdf_EMODB_50_train_013
# %store -r featuresdf_EMODB_60_test_013
# %store -r featuresdf_EMODB_60_train_013
# %store -r featuresdf_EMODB_70_test_013
# %store -r featuresdf_EMODB_70_train_013
# %store -r featuresdf_EMODB_80_test_013
# %store -r featuresdf_EMODB_80_train_013
# %store -r featuresdf_EMODB_90_test_013
# %store -r featuresdf_EMODB_90_train_013
# %store -r featuresdf_EMODB_100_test_013
# %store -r featuresdf_EMODB_100_train_013

# %store -r featuresdf_EMODB_10_test_014
# %store -r featuresdf_EMODB_10_train_014
# %store -r featuresdf_EMODB_20_test_014
# %store -r featuresdf_EMODB_20_train_014
# %store -r featuresdf_EMODB_30_test_014
# %store -r featuresdf_EMODB_30_train_014
# %store -r featuresdf_EMODB_40_test_014
# %store -r featuresdf_EMODB_40_train_014
# %store -r featuresdf_EMODB_50_test_014
# %store -r featuresdf_EMODB_50_train_014
# %store -r featuresdf_EMODB_60_test_014
# %store -r featuresdf_EMODB_60_train_014
# %store -r featuresdf_EMODB_70_test_014
# %store -r featuresdf_EMODB_70_train_014
# %store -r featuresdf_EMODB_80_test_014
# %store -r featuresdf_EMODB_80_train_014
# %store -r featuresdf_EMODB_90_test_014
# %store -r featuresdf_EMODB_90_train_014
# %store -r featuresdf_EMODB_100_test_014
# %store -r featuresdf_EMODB_100_train_014

#%store -r featuresdf_EMODB_10_test_015
#%store -r featuresdf_EMODB_10_train_015
# %store -r featuresdf_EMODB_20_test_015
# %store -r featuresdf_EMODB_20_train_015
# %store -r featuresdf_EMODB_30_test_015
# %store -r featuresdf_EMODB_30_train_015
# %store -r featuresdf_EMODB_40_test_015
# %store -r featuresdf_EMODB_40_train_015
# %store -r featuresdf_EMODB_50_test_015
# %store -r featuresdf_EMODB_50_train_015
# %store -r featuresdf_EMODB_60_test_015
# %store -r featuresdf_EMODB_60_train_015
# %store -r featuresdf_EMODB_70_test_015
# %store -r featuresdf_EMODB_70_train_015
# %store -r featuresdf_EMODB_80_test_015
# %store -r featuresdf_EMODB_80_train_015
# %store -r featuresdf_EMODB_90_test_015
# %store -r featuresdf_EMODB_90_train_015
# %store -r featuresdf_EMODB_100_test_015
# %store -r featuresdf_EMODB_100_train_015

# %store -r featuresdf_EMODB_10_test_016
# %store -r featuresdf_EMODB_10_train_016
# %store -r featuresdf_EMODB_20_test_016
# %store -r featuresdf_EMODB_20_train_016
# %store -r featuresdf_EMODB_30_test_016
# %store -r featuresdf_EMODB_30_train_016
# %store -r featuresdf_EMODB_40_test_016
# %store -r featuresdf_EMODB_40_train_016
# %store -r featuresdf_EMODB_50_test_016
# %store -r featuresdf_EMODB_50_train_016
# %store -r featuresdf_EMODB_60_test_016
# %store -r featuresdf_EMODB_60_train_016
# %store -r featuresdf_EMODB_70_test_016
# %store -r featuresdf_EMODB_70_train_016
# %store -r featuresdf_EMODB_80_test_016
# %store -r featuresdf_EMODB_80_train_016
# %store -r featuresdf_EMODB_90_test_016
# %store -r featuresdf_EMODB_90_train_016
# %store -r featuresdf_EMODB_100_test_016
# %store -r featuresdf_EMODB_100_train_016

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
import numpy as np

featuresdf_test_EMODB = featuresdf_EMODB_100_test_016
featuresdf_train_EMODB = featuresdf_EMODB_100_train_016

# %store featuresdf_test_EMODB
# %store featuresdf_train_EMODB

x_test = np.array(featuresdf_test_EMODB.feature.tolist())
y_test = np.array(featuresdf_test_EMODB.class_label.tolist())

le = LabelEncoder()
y_test = to_categorical(le.fit_transform(y_test))

x_train = np.array(featuresdf_train_EMODB.feature.tolist())
y_train = np.array(featuresdf_train_EMODB.class_label.tolist())

y_train = to_categorical(le.fit_transform(y_train))

# %store x_train 
# %store x_test 
# %store y_train 
# %store y_test 

y_train = np.array(featuresdf_train_EMODB.class_label.tolist())

y_test = np.array(featuresdf_test_EMODB.class_label.tolist())

y_train = np.append(y_train, y_test)

yy = to_categorical(le.fit_transform(y_train))

# %store yy 
# %store le
# Out:
# Stored 'featuresdf_test_EMODB' (DataFrame)
# Stored 'featuresdf_train_EMODB' (DataFrame)
# Stored 'x_train' (ndarray)
# Stored 'x_test' (ndarray)
# Stored 'y_train' (ndarray)
# Stored 'y_test' (ndarray)
# Stored 'yy' (ndarray)
# Stored 'le' (LabelEncoder)
