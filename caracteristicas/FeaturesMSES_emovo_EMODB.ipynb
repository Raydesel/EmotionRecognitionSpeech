# %%
# %store -r featuresdf_12_test_01
# %store -r featuresdf_12_train_01
# %store -r featuresdf_24_test_01
# %store -r featuresdf_24_train_01
# %store -r featuresdf_36_test_01
# %store -r featuresdf_36_train_01
# %store -r featuresdf_48_test_01
# %store -r featuresdf_48_train_01

# %store -r featuresdf_12_test_02
# %store -r featuresdf_12_train_02
# %store -r featuresdf_24_test_02
# %store -r featuresdf_24_train_02
# %store -r featuresdf_36_test_02
# %store -r featuresdf_36_train_02
# %store -r featuresdf_48_test_02
# %store -r featuresdf_48_train_02

# %store -r featuresdf_12_test_03
# %store -r featuresdf_12_train_03
# %store -r featuresdf_24_test_03
# %store -r featuresdf_24_train_03
# %store -r featuresdf_36_test_03
# %store -r featuresdf_36_train_03
# %store -r featuresdf_48_test_03
# %store -r featuresdf_48_train_03

# %store -r featuresdf_12_test_04
# %store -r featuresdf_12_train_04
# %store -r featuresdf_24_test_04
# %store -r featuresdf_24_train_04
# %store -r featuresdf_36_test_04
# %store -r featuresdf_36_train_04
# %store -r featuresdf_48_test_04
# %store -r featuresdf_48_train_04

# %%
# %store -r featuresdf_10_test_05
# %store -r featuresdf_10_train_05
# %store -r featuresdf_20_test_05
# %store -r featuresdf_20_train_05
# %store -r featuresdf_30_test_05
# %store -r featuresdf_30_train_05
# %store -r featuresdf_40_test_05
# %store -r featuresdf_40_train_05
# %store -r featuresdf_50_test_05
# %store -r featuresdf_50_train_05
# %store -r featuresdf_60_test_05
# %store -r featuresdf_60_train_05
# %store -r featuresdf_70_test_05
# %store -r featuresdf_70_train_05
# %store -r featuresdf_80_test_05
# %store -r featuresdf_80_train_05
# %store -r featuresdf_90_test_05
# %store -r featuresdf_90_train_05
# %store -r featuresdf_100_test_05
# %store -r featuresdf_100_train_05

# %store -r featuresdf_10_test_06
# %store -r featuresdf_10_train_06
# %store -r featuresdf_20_test_06
# %store -r featuresdf_20_train_06
# %store -r featuresdf_30_test_06
# %store -r featuresdf_30_train_06
# %store -r featuresdf_40_test_06
# %store -r featuresdf_40_train_06
# %store -r featuresdf_50_test_06
# %store -r featuresdf_50_train_06
# %store -r featuresdf_60_test_06
# %store -r featuresdf_60_train_06
# %store -r featuresdf_70_test_06
# %store -r featuresdf_70_train_06
# %store -r featuresdf_80_test_06
# %store -r featuresdf_80_train_06
# %store -r featuresdf_90_test_06
# %store -r featuresdf_90_train_06
# %store -r featuresdf_100_test_06
# %store -r featuresdf_100_train_06

# %store -r featuresdf_10_test_07
# %store -r featuresdf_10_train_07
# %store -r featuresdf_20_test_07
# %store -r featuresdf_20_train_07
# %store -r featuresdf_30_test_07
# %store -r featuresdf_30_train_07
# %store -r featuresdf_40_test_07
# %store -r featuresdf_40_train_07
# %store -r featuresdf_50_test_07
# %store -r featuresdf_50_train_07
# %store -r featuresdf_60_test_07
# %store -r featuresdf_60_train_07
# %store -r featuresdf_70_test_07
# %store -r featuresdf_70_train_07
# %store -r featuresdf_80_test_07
# %store -r featuresdf_80_train_07
# %store -r featuresdf_90_test_07
# %store -r featuresdf_90_train_07
# %store -r featuresdf_100_test_07
# %store -r featuresdf_100_train_07

# %store -r featuresdf_10_test_08
# %store -r featuresdf_10_train_08
# %store -r featuresdf_20_test_08
# %store -r featuresdf_20_train_08
# %store -r featuresdf_30_test_08
# %store -r featuresdf_30_train_08
# %store -r featuresdf_40_test_08
# %store -r featuresdf_40_train_08
# %store -r featuresdf_50_test_08
# %store -r featuresdf_50_train_08
# %store -r featuresdf_60_test_08
# %store -r featuresdf_60_train_08
# %store -r featuresdf_70_test_08
# %store -r featuresdf_70_train_08
# %store -r featuresdf_80_test_08
# %store -r featuresdf_80_train_08
# %store -r featuresdf_90_test_08
# %store -r featuresdf_90_train_08
# %store -r featuresdf_100_test_08
# %store -r featuresdf_100_train_08

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
import numpy as np

featuresdf_test_emovo = featuresdf_100_test_06
featuresdf_train_emovo = featuresdf_100_train_06

# %store featuresdf_test_emovo
# %store featuresdf_train_emovo

# Convert features and corresponding classification labels into numpy arrays
x_test = np.array(featuresdf_test_emovo.feature.tolist())
y_test = np.array(featuresdf_test_emovo.class_label.tolist())

le = LabelEncoder()
y_test = to_categorical(le.fit_transform(y_test))

x_train = np.array(featuresdf_train_emovo.feature.tolist())
y_train= np.array(featuresdf_train_emovo.class_label.tolist())

y_train = to_categorical(le.fit_transform(y_train))

# %store x_train 
# %store x_test 
# %store y_train 
# %store y_test 

y_test = np.array(featuresdf_test_emovo.class_label.tolist())

y_train = np.array(featuresdf_train_emovo.class_label.tolist())

y_train = np.append(y_train, y_test)

yy = to_categorical(le.fit_transform(y_train))

# %store yy 
# %store le
# Out:
# Using TensorFlow backend.
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# %store -r featuresdf_EMODB_12_test_01
# %store -r featuresdf_EMODB_12_train_01
# %store -r featuresdf_EMODB_24_test_01
# %store -r featuresdf_EMODB_24_train_01
# %store -r featuresdf_EMODB_36_test_01
# %store -r featuresdf_EMODB_36_train_01
# %store -r featuresdf_EMODB_48_test_01
# %store -r featuresdf_EMODB_48_train_01

# %store -r featuresdf_EMODB_12_test_02
# %store -r featuresdf_EMODB_12_train_02
# %store -r featuresdf_EMODB_24_test_02
# %store -r featuresdf_EMODB_24_train_02
# %store -r featuresdf_EMODB_36_test_02
# %store -r featuresdf_EMODB_36_train_02
# %store -r featuresdf_EMODB_48_test_02
# %store -r featuresdf_EMODB_48_train_02

# %store -r featuresdf_EMODB_12_test_03
# %store -r featuresdf_EMODB_12_train_03
# %store -r featuresdf_EMODB_24_test_03
# %store -r featuresdf_EMODB_24_train_03
# %store -r featuresdf_EMODB_36_test_03
# %store -r featuresdf_EMODB_36_train_03
# %store -r featuresdf_EMODB_48_test_03
# %store -r featuresdf_EMODB_48_train_03

# %store -r featuresdf_EMODB_12_test_04
# %store -r featuresdf_EMODB_12_train_04
# %store -r featuresdf_EMODB_24_test_04
# %store -r featuresdf_EMODB_24_train_04
# %store -r featuresdf_EMODB_36_test_04
# %store -r featuresdf_EMODB_36_train_04
# %store -r featuresdf_EMODB_48_test_04
# %store -r featuresdf_EMODB_48_train_04

# %%
# %store -r featuresdf_EMODB_10_test_05
# %store -r featuresdf_EMODB_10_train_05
# %store -r featuresdf_EMODB_20_test_05
# %store -r featuresdf_EMODB_20_train_05
# %store -r featuresdf_EMODB_30_test_05
# %store -r featuresdf_EMODB_30_train_05
# %store -r featuresdf_EMODB_40_test_05
# %store -r featuresdf_EMODB_40_train_05
# %store -r featuresdf_EMODB_50_test_05
# %store -r featuresdf_EMODB_50_train_05
# %store -r featuresdf_EMODB_60_test_05
# %store -r featuresdf_EMODB_60_train_05
# %store -r featuresdf_EMODB_70_test_05
# %store -r featuresdf_EMODB_70_train_05
# %store -r featuresdf_EMODB_80_test_05
# %store -r featuresdf_EMODB_80_train_05
# %store -r featuresdf_EMODB_90_test_05
# %store -r featuresdf_EMODB_90_train_05
# %store -r featuresdf_EMODB_100_test_05
# %store -r featuresdf_EMODB_100_train_05

# %store -r featuresdf_EMODB_10_test_06
# %store -r featuresdf_EMODB_10_train_06
# %store -r featuresdf_EMODB_20_test_06
# %store -r featuresdf_EMODB_20_train_06
# %store -r featuresdf_EMODB_30_test_06
# %store -r featuresdf_EMODB_30_train_06
# %store -r featuresdf_EMODB_40_test_06
# %store -r featuresdf_EMODB_40_train_06
# %store -r featuresdf_EMODB_50_test_06
# %store -r featuresdf_EMODB_50_train_06
# %store -r featuresdf_EMODB_60_test_06
# %store -r featuresdf_EMODB_60_train_06
# %store -r featuresdf_EMODB_70_test_06
# %store -r featuresdf_EMODB_70_train_06
# %store -r featuresdf_EMODB_80_test_06
# %store -r featuresdf_EMODB_80_train_06
# %store -r featuresdf_EMODB_90_test_06
# %store -r featuresdf_EMODB_90_train_06
# %store -r featuresdf_EMODB_100_test_06
# %store -r featuresdf_EMODB_100_train_06

# %store -r featuresdf_EMODB_10_test_07
# %store -r featuresdf_EMODB_10_train_07
# %store -r featuresdf_EMODB_20_test_07
# %store -r featuresdf_EMODB_20_train_07
# %store -r featuresdf_EMODB_30_test_07
# %store -r featuresdf_EMODB_30_train_07
# %store -r featuresdf_EMODB_40_test_07
# %store -r featuresdf_EMODB_40_train_07
# %store -r featuresdf_EMODB_50_test_07
# %store -r featuresdf_EMODB_50_train_07
# %store -r featuresdf_EMODB_60_test_07
# %store -r featuresdf_EMODB_60_train_07
# %store -r featuresdf_EMODB_70_test_07
# %store -r featuresdf_EMODB_70_train_07
# %store -r featuresdf_EMODB_80_test_07
# %store -r featuresdf_EMODB_80_train_07
# %store -r featuresdf_EMODB_90_test_07
# %store -r featuresdf_EMODB_90_train_07
# %store -r featuresdf_EMODB_100_test_07
# %store -r featuresdf_EMODB_100_train_07

# %store -r featuresdf_EMODB_10_test_08
# %store -r featuresdf_EMODB_10_train_08
# %store -r featuresdf_EMODB_20_test_08
# %store -r featuresdf_EMODB_20_train_08
# %store -r featuresdf_EMODB_30_test_08
# %store -r featuresdf_EMODB_30_train_08
# %store -r featuresdf_EMODB_40_test_08
# %store -r featuresdf_EMODB_40_train_08
# %store -r featuresdf_EMODB_50_test_08
# %store -r featuresdf_EMODB_50_train_08
# %store -r featuresdf_EMODB_60_test_08
# %store -r featuresdf_EMODB_60_train_08
# %store -r featuresdf_EMODB_70_test_08
# %store -r featuresdf_EMODB_70_train_08
# %store -r featuresdf_EMODB_80_test_08
# %store -r featuresdf_EMODB_80_train_08
# %store -r featuresdf_EMODB_90_test_08
# %store -r featuresdf_EMODB_90_train_08
# %store -r featuresdf_EMODB_100_test_08
# %store -r featuresdf_EMODB_100_train_08

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
import numpy as np

featuresdf_test_EMODB = featuresdf_EMODB_10_test_05
featuresdf_train_EMODB = featuresdf_EMODB_10_train_05

# %store featuresdf_test_EMODB
# %store featuresdf_train_EMODB

x_test = np.array(featuresdf_test_EMODB.feature.tolist())
y_test = np.array(featuresdf_test_EMODB.class_label.tolist())

le = LabelEncoder()
y_test = to_categorical(le.fit_transform(y_test))

x_train = np.array(featuresdf_train_EMODB.feature.tolist())
y_train = np.array(featuresdf_train_EMODB.class_label.tolist())

y_train = to_categorical(le.fit_transform(y_train))

# %store x_train 
# %store x_test 
# %store y_train 
# %store y_test 

y_train = np.array(featuresdf_train_EMODB.class_label.tolist())

y_test = np.array(featuresdf_test_EMODB.class_label.tolist())

y_train = np.append(y_train, y_test)

yy = to_categorical(le.fit_transform(y_train))

# %store yy 
# %store le
# Out:
# Stored 'featuresdf_test_EMODB' (DataFrame)
# Stored 'featuresdf_train_EMODB' (DataFrame)
# Stored 'x_train' (ndarray)
# Stored 'x_test' (ndarray)
# Stored 'y_train' (ndarray)
# Stored 'y_test' (ndarray)
# Stored 'yy' (ndarray)
# Stored 'le' (LabelEncoder)
