# %%
# %store -r featuresdf_12_test_9
# %store -r featuresdf_12_train_9
# %store -r featuresdf_24_test_9
# %store -r featuresdf_24_train_9
# %store -r featuresdf_36_test_9
# %store -r featuresdf_36_train_9
# %store -r featuresdf_48_test_9
# %store -r featuresdf_48_train_9

# %store -r featuresdf_12_test_10
# %store -r featuresdf_12_train_10
# %store -r featuresdf_24_test_10
# %store -r featuresdf_24_train_10
# %store -r featuresdf_36_test_10
# %store -r featuresdf_36_train_10
# %store -r featuresdf_48_test_10
# %store -r featuresdf_48_train_10

# %store -r featuresdf_12_test_11
# %store -r featuresdf_12_train_11
# %store -r featuresdf_24_test_11
# %store -r featuresdf_24_train_11
# %store -r featuresdf_36_test_11
# %store -r featuresdf_36_train_11
# %store -r featuresdf_48_test_11
# %store -r featuresdf_48_train_11

# %store -r featuresdf_12_test_12
# %store -r featuresdf_12_train_12
# %store -r featuresdf_24_test_12
# %store -r featuresdf_24_train_12
# %store -r featuresdf_36_test_12
# %store -r featuresdf_36_train_12
# %store -r featuresdf_48_test_12
# %store -r featuresdf_48_train_12

# %%
# %store -r featuresdf_10_test_13
# %store -r featuresdf_10_train_13
# %store -r featuresdf_20_test_13
# %store -r featuresdf_20_train_13
# %store -r featuresdf_30_test_13
# %store -r featuresdf_30_train_13
# %store -r featuresdf_40_test_13
# %store -r featuresdf_40_train_13
# %store -r featuresdf_50_test_13
# %store -r featuresdf_50_train_13
# %store -r featuresdf_60_test_13
# %store -r featuresdf_60_train_13
# %store -r featuresdf_70_test_13
# %store -r featuresdf_70_train_13
# %store -r featuresdf_80_test_13
# %store -r featuresdf_80_train_13
# %store -r featuresdf_90_test_13
# %store -r featuresdf_90_train_13
# %store -r featuresdf_100_test_13
# %store -r featuresdf_100_train_13

# %store -r featuresdf_10_test_14
# %store -r featuresdf_10_train_14
# %store -r featuresdf_20_test_14
# %store -r featuresdf_20_train_14
# %store -r featuresdf_30_test_14
# %store -r featuresdf_30_train_14
# %store -r featuresdf_40_test_14
# %store -r featuresdf_40_train_14
# %store -r featuresdf_50_test_14
# %store -r featuresdf_50_train_14
# %store -r featuresdf_60_test_14
# %store -r featuresdf_60_train_14
# %store -r featuresdf_70_test_14
# %store -r featuresdf_70_train_14
# %store -r featuresdf_80_test_14
# %store -r featuresdf_80_train_14
# %store -r featuresdf_90_test_14
# %store -r featuresdf_90_train_14
# %store -r featuresdf_100_test_14
# %store -r featuresdf_100_train_14

# %store -r featuresdf_10_test_15
# %store -r featuresdf_10_train_15
# %store -r featuresdf_20_test_15
# %store -r featuresdf_20_train_15
# %store -r featuresdf_30_test_15
# %store -r featuresdf_30_train_15
# %store -r featuresdf_40_test_15
# %store -r featuresdf_40_train_15
# %store -r featuresdf_50_test_15
# %store -r featuresdf_50_train_15
# %store -r featuresdf_60_test_15
# %store -r featuresdf_60_train_15
# %store -r featuresdf_70_test_15
# %store -r featuresdf_70_train_15
# %store -r featuresdf_80_test_15
# %store -r featuresdf_80_train_15
# %store -r featuresdf_90_test_15
# %store -r featuresdf_90_train_15
# %store -r featuresdf_100_test_15
# %store -r featuresdf_100_train_15

# %store -r featuresdf_10_test_16
# %store -r featuresdf_10_train_16
# %store -r featuresdf_20_test_16
# %store -r featuresdf_20_train_16
# %store -r featuresdf_30_test_16
# %store -r featuresdf_30_train_16
# %store -r featuresdf_40_test_16
# %store -r featuresdf_40_train_16
# %store -r featuresdf_50_test_16
# %store -r featuresdf_50_train_16
# %store -r featuresdf_60_test_16
# %store -r featuresdf_60_train_16
# %store -r featuresdf_70_test_16
# %store -r featuresdf_70_train_16
# %store -r featuresdf_80_test_16
# %store -r featuresdf_80_train_16
# %store -r featuresdf_90_test_16
# %store -r featuresdf_90_train_16
# %store -r featuresdf_100_test_16
# %store -r featuresdf_100_train_16

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
import numpy as np

featuresdf_test_emovo = featuresdf_40_test_15
featuresdf_train_emovo = featuresdf_40_train_15

# %store featuresdf_test_emovo
# %store featuresdf_train_emovo

# Convert features and corresponding classification labels into numpy arrays
x_test = np.array(featuresdf_test_emovo.feature.tolist())
y_test = np.array(featuresdf_test_emovo.class_label.tolist())

le = LabelEncoder()
y_test = to_categorical(le.fit_transform(y_test))

x_train = np.array(featuresdf_train_emovo.feature.tolist())
y_train= np.array(featuresdf_train_emovo.class_label.tolist())

y_train = to_categorical(le.fit_transform(y_train))

# %store x_train 
# %store x_test 
# %store y_train 
# %store y_test 

y_test = np.array(featuresdf_test_emovo.class_label.tolist())

y_train = np.array(featuresdf_train_emovo.class_label.tolist())

y_train = np.append(y_train, y_test)

yy = to_categorical(le.fit_transform(y_train))

# %store yy 
# %store le
# Out:
# Stored 'featuresdf_test_emovo' (DataFrame)
# Stored 'featuresdf_train_emovo' (DataFrame)
# Stored 'x_train' (ndarray)
# Stored 'x_test' (ndarray)
# Stored 'y_train' (ndarray)
# Stored 'y_test' (ndarray)
# Stored 'yy' (ndarray)
# Stored 'le' (LabelEncoder)

# %%
# %store -r featuresdf_EMODB_12_test_9
# %store -r featuresdf_EMODB_12_train_9
# %store -r featuresdf_EMODB_24_test_9
# %store -r featuresdf_EMODB_24_train_9
# %store -r featuresdf_EMODB_36_test_9
# %store -r featuresdf_EMODB_36_train_9
# %store -r featuresdf_EMODB_48_test_9
# %store -r featuresdf_EMODB_48_train_9

# %store -r featuresdf_EMODB_12_test_10
# %store -r featuresdf_EMODB_12_train_10
# %store -r featuresdf_EMODB_24_test_10
# %store -r featuresdf_EMODB_24_train_10
# %store -r featuresdf_EMODB_36_test_10
# %store -r featuresdf_EMODB_36_train_10
# %store -r featuresdf_EMODB_48_test_10
# %store -r featuresdf_EMODB_48_train_10

# %store -r featuresdf_EMODB_12_test_11
# %store -r featuresdf_EMODB_12_train_11
# %store -r featuresdf_EMODB_24_test_11
# %store -r featuresdf_EMODB_24_train_11
# %store -r featuresdf_EMODB_36_test_11
# %store -r featuresdf_EMODB_36_train_11
# %store -r featuresdf_EMODB_48_test_11
# %store -r featuresdf_EMODB_48_train_11

# %store -r featuresdf_EMODB_12_test_12
# %store -r featuresdf_EMODB_12_train_12
# %store -r featuresdf_EMODB_24_test_12
# %store -r featuresdf_EMODB_24_train_12
# %store -r featuresdf_EMODB_36_test_12
# %store -r featuresdf_EMODB_36_train_12
# %store -r featuresdf_EMODB_48_test_12
# %store -r featuresdf_EMODB_48_train_12

# %%
# %store -r featuresdf_EMODB_10_test_13
# %store -r featuresdf_EMODB_10_train_13
# %store -r featuresdf_EMODB_20_test_13
# %store -r featuresdf_EMODB_20_train_13
# %store -r featuresdf_EMODB_30_test_13
# %store -r featuresdf_EMODB_30_train_13
# %store -r featuresdf_EMODB_40_test_13
# %store -r featuresdf_EMODB_40_train_13
# %store -r featuresdf_EMODB_50_test_13
# %store -r featuresdf_EMODB_50_train_13
# %store -r featuresdf_EMODB_60_test_13
# %store -r featuresdf_EMODB_60_train_13
# %store -r featuresdf_EMODB_70_test_13
# %store -r featuresdf_EMODB_70_train_13
# %store -r featuresdf_EMODB_80_test_13
# %store -r featuresdf_EMODB_80_train_13
# %store -r featuresdf_EMODB_90_test_13
# %store -r featuresdf_EMODB_90_train_13
# %store -r featuresdf_EMODB_100_test_13
# %store -r featuresdf_EMODB_100_train_13

# %store -r featuresdf_EMODB_10_test_14
# %store -r featuresdf_EMODB_10_train_14
# %store -r featuresdf_EMODB_20_test_14
# %store -r featuresdf_EMODB_20_train_14
# %store -r featuresdf_EMODB_30_test_14
# %store -r featuresdf_EMODB_30_train_14
# %store -r featuresdf_EMODB_40_test_14
# %store -r featuresdf_EMODB_40_train_14
# %store -r featuresdf_EMODB_50_test_14
# %store -r featuresdf_EMODB_50_train_14
# %store -r featuresdf_EMODB_60_test_14
# %store -r featuresdf_EMODB_60_train_14
# %store -r featuresdf_EMODB_70_test_14
# %store -r featuresdf_EMODB_70_train_14
# %store -r featuresdf_EMODB_80_test_14
# %store -r featuresdf_EMODB_80_train_14
# %store -r featuresdf_EMODB_90_test_14
# %store -r featuresdf_EMODB_90_train_14
# %store -r featuresdf_EMODB_100_test_14
# %store -r featuresdf_EMODB_100_train_14

# %store -r featuresdf_EMODB_10_test_15
# %store -r featuresdf_EMODB_10_train_15
# %store -r featuresdf_EMODB_20_test_15
# %store -r featuresdf_EMODB_20_train_15
# %store -r featuresdf_EMODB_30_test_15
# %store -r featuresdf_EMODB_30_train_15
# %store -r featuresdf_EMODB_40_test_15
# %store -r featuresdf_EMODB_40_train_15
# %store -r featuresdf_EMODB_50_test_15
# %store -r featuresdf_EMODB_50_train_15
# %store -r featuresdf_EMODB_60_test_15
# %store -r featuresdf_EMODB_60_train_15
# %store -r featuresdf_EMODB_70_test_15
# %store -r featuresdf_EMODB_70_train_15
# %store -r featuresdf_EMODB_80_test_15
# %store -r featuresdf_EMODB_80_train_15
# %store -r featuresdf_EMODB_90_test_15
# %store -r featuresdf_EMODB_90_train_15
# %store -r featuresdf_EMODB_100_test_15
# %store -r featuresdf_EMODB_100_train_15

# %store -r featuresdf_EMODB_10_test_16
# %store -r featuresdf_EMODB_10_train_16
# %store -r featuresdf_EMODB_20_test_16
# %store -r featuresdf_EMODB_20_train_16
# %store -r featuresdf_EMODB_30_test_16
# %store -r featuresdf_EMODB_30_train_16
# %store -r featuresdf_EMODB_40_test_16
# %store -r featuresdf_EMODB_40_train_16
# %store -r featuresdf_EMODB_50_test_16
# %store -r featuresdf_EMODB_50_train_16
# %store -r featuresdf_EMODB_60_test_16
# %store -r featuresdf_EMODB_60_train_16
# %store -r featuresdf_EMODB_70_test_16
# %store -r featuresdf_EMODB_70_train_16
# %store -r featuresdf_EMODB_80_test_16
# %store -r featuresdf_EMODB_80_train_16
# %store -r featuresdf_EMODB_90_test_16
# %store -r featuresdf_EMODB_90_train_16
# %store -r featuresdf_EMODB_100_test_16
# %store -r featuresdf_EMODB_100_train_16

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
import numpy as np

featuresdf_test_EMODB = featuresdf_EMODB_90_test_16
featuresdf_train_EMODB = featuresdf_EMODB_90_train_16

# %store featuresdf_test_EMODB
# %store featuresdf_train_EMODB

x_test = np.array(featuresdf_test_EMODB.feature.tolist())
y_test = np.array(featuresdf_test_EMODB.class_label.tolist())

le = LabelEncoder()
y_test = to_categorical(le.fit_transform(y_test))

x_train = np.array(featuresdf_train_EMODB.feature.tolist())
y_train = np.array(featuresdf_train_EMODB.class_label.tolist())

y_train = to_categorical(le.fit_transform(y_train))

# %store x_train 
# %store x_test 
# %store y_train 
# %store y_test 

y_train = np.array(featuresdf_train_EMODB.class_label.tolist())

y_test = np.array(featuresdf_test_EMODB.class_label.tolist())

y_train = np.append(y_train, y_test)

yy = to_categorical(le.fit_transform(y_train))

# %store yy 
# %store le
# Out:
# Stored 'featuresdf_test_EMODB' (DataFrame)
# Stored 'featuresdf_train_EMODB' (DataFrame)
# Stored 'x_train' (ndarray)
# Stored 'x_test' (ndarray)
# Stored 'y_train' (ndarray)
# Stored 'y_test' (ndarray)
# Stored 'yy' (ndarray)
# Stored 'le' (LabelEncoder)
