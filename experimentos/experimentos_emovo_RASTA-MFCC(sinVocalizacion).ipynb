# %% [markdown]
# ## emovo Experimento 1
#
# ### Cantidad de coeficientes 12, 24, 36, 48, Usando ventana tipo 2, sin preénfasis, ancho de band completo (fs/2), tamaño de frame de 30ms y traslape de 50
#
# ### Window=2  preénfasis=0 f_max = fs/2  frame=0.03 overlap=50

# %% [markdown]
# # MFCC

# %%
import matplotlib.pyplot as plt

mfcc = mel_freq_ceps_coef(r'\Users\SACKRAY7\Desktop\Tesis\emovo\EMOVO\f1\gio-f1-b1.wav',1,1)

plt.figure(5)
plt.plot(mfcc.coef[11,:])
plt.figure(6)
plt.plot(mfcc.mfccsscalade)

plt.figure(4)
cepst = mfcc.cepstrum
plt.imshow(cepst[::-1],cmap=plt.get_cmap('jet'),extent = [0,mfcc.n_frames,1,mfcc.n_filters],aspect="auto")

plt.figure(3)
espectrogram = mfcc.energy
plt.imshow(espectrogram[::-1],cmap=plt.get_cmap('jet'),extent = [0,mfcc.n_frames,mfcc.f_min,mfcc.f_max],aspect="auto")

plt.figure(1)
plt.plot(mfcc.signal)

plt.figure(2)
plt.plot(mfcc.window_data)

# %%
inicio = default_timer()

featuresdf_12_test_9=extract_features_test_emovo()

featuresdf_12_train_9=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 4.975689855000001

# %%
inicio = default_timer()

featuresdf_24_test_9=extract_features_test_emovo()

featuresdf_24_train_9=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 4.92158514

# %%
inicio = default_timer()

featuresdf_36_test_9=extract_features_test_emovo()

featuresdf_36_train_9=extract_features_train_emovo() 

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 6.63348779333334

# %%
inicio = default_timer()

featuresdf_48_test_9=extract_features_test_emovo()

featuresdf_48_train_9=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 10.003081109999993

# %%
# %store featuresdf_12_test_9
# %store featuresdf_12_train_9
# %store featuresdf_24_test_9
# %store featuresdf_24_train_9
# %store featuresdf_36_test_9
# %store featuresdf_36_train_9
# %store featuresdf_48_test_9
# %store featuresdf_48_train_9
# Out:
# Stored 'featuresdf_12_test_9' (DataFrame)
# Stored 'featuresdf_12_train_9' (DataFrame)
# Stored 'featuresdf_24_test_9' (DataFrame)
# Stored 'featuresdf_24_train_9' (DataFrame)
# Stored 'featuresdf_36_test_9' (DataFrame)
# Stored 'featuresdf_36_train_9' (DataFrame)
# Stored 'featuresdf_48_test_9' (DataFrame)
# Stored 'featuresdf_48_train_9' (DataFrame)

# %% [markdown]
# # RASTA-MFCC

# %%
inicio = default_timer()

featuresdf_12_test_10=extract_features_test_emovo()

featuresdf_12_train_10=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 7.374354340000021

# %%
inicio = default_timer()

featuresdf_24_test_10=extract_features_test_emovo()

featuresdf_24_train_10=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 6.88315304000001

# %%
inicio = default_timer()

featuresdf_36_test_10=extract_features_test_emovo()

featuresdf_36_train_10=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 7.744672775000011

# %%
inicio = default_timer()

featuresdf_48_test_10=extract_features_test_emovo()

featuresdf_48_train_10=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 633.3518278566667

# %%
# %store featuresdf_12_test_10
# %store featuresdf_12_train_10
# %store featuresdf_24_test_10
# %store featuresdf_24_train_10
# %store featuresdf_36_test_10
# %store featuresdf_36_train_10
# %store featuresdf_48_test_10
# %store featuresdf_48_train_10
# Out:
# Stored 'featuresdf_12_test_10' (DataFrame)
# Stored 'featuresdf_12_train_10' (DataFrame)
# Stored 'featuresdf_24_test_10' (DataFrame)
# Stored 'featuresdf_24_train_10' (DataFrame)
# Stored 'featuresdf_36_test_10' (DataFrame)
# Stored 'featuresdf_36_train_10' (DataFrame)
# Stored 'featuresdf_48_test_10' (DataFrame)
# Stored 'featuresdf_48_train_10' (DataFrame)

# %% [markdown]
# ## emovo Experimento 1.5
#
# ### Cantidad de coeficientes 12, 24, 36, 48, Usando ventana tipo 2, Con preénfasis 0.97, ancho de band completo (fs/2), tamaño de frame de 30ms y traslape de 50
#
# ### Window=2 preénfasis=0.97 f_max = fs/2 frame=0.03 overlap=50

# %% [markdown]
# # MFCC

# %%
inicio = default_timer()

featuresdf_12_test_11=extract_features_test_emovo()

featuresdf_12_train_11=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 5.421917201666656

# %%
inicio = default_timer()

featuresdf_24_test_11=extract_features_test_emovo()

featuresdf_24_train_11=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 6.801197269999951

# %%
inicio = default_timer()

featuresdf_36_test_11=extract_features_test_emovo()

featuresdf_36_train_11=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 8.679176888333556

# %%
inicio = default_timer()

featuresdf_48_test_11=extract_features_test_emovo()

featuresdf_48_train_11=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 10.680859836666544

# %%
# %store featuresdf_12_test_11
# %store featuresdf_12_train_11
# %store featuresdf_24_test_11
# %store featuresdf_24_train_11
# %store featuresdf_36_test_11
# %store featuresdf_36_train_11
# %store featuresdf_48_test_11
# %store featuresdf_48_train_11
# Out:
# Stored 'featuresdf_12_test_11' (DataFrame)
# Stored 'featuresdf_12_train_11' (DataFrame)
# Stored 'featuresdf_24_test_11' (DataFrame)
# Stored 'featuresdf_24_train_11' (DataFrame)
# Stored 'featuresdf_36_test_11' (DataFrame)
# Stored 'featuresdf_36_train_11' (DataFrame)
# Stored 'featuresdf_48_test_11' (DataFrame)
# Stored 'featuresdf_48_train_11' (DataFrame)

# %% [markdown]
# # RASTA-MFCC

# %%
inicio = default_timer()

featuresdf_12_test_12=extract_features_test_emovo()

featuresdf_12_train_12=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 6.464547603333388

# %%
iinicio = default_timer()

featuresdf_24_test_12=extract_features_test_emovo()

featuresdf_24_train_12=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 19.13580642166683

# %%
inicio = default_timer()

featuresdf_36_test_12=extract_features_test_emovo()

featuresdf_36_train_12=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 10.549207091666661

# %%
inicio = default_timer()

featuresdf_48_test_12=extract_features_test_emovo()

featuresdf_48_train_12=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 10.646044506666659

# %%
# %store featuresdf_12_test_12
# %store featuresdf_12_train_12
# %store featuresdf_24_test_12
# %store featuresdf_24_train_12
# %store featuresdf_36_test_12
# %store featuresdf_36_train_12
# %store featuresdf_48_test_12
# %store featuresdf_48_train_12
# Out:
# Stored 'featuresdf_12_test_12' (DataFrame)
# Stored 'featuresdf_12_train_12' (DataFrame)
# Stored 'featuresdf_24_test_12' (DataFrame)
# Stored 'featuresdf_24_train_12' (DataFrame)
# Stored 'featuresdf_36_test_12' (DataFrame)
# Stored 'featuresdf_36_train_12' (DataFrame)
# Stored 'featuresdf_48_test_12' (DataFrame)
# Stored 'featuresdf_48_train_12' (DataFrame)

# %% [markdown]
# ## emovo Experimento 2
#
# ### Cantidad de coeficientes el mejor resultado de los dos experimentos anteriores, Usando ventana tipo 2, sin y con preénfasis, ancho de banda completo (fs/2), tamaño de frame desde 10ms hasta 100 ms y traslape de 50%
#
# ### n_coef=24  Window=2  preénfasis=0.0 f_max = fs/2  frame=10-100 overlap=50
#
# ## MFCC

# %%
inicio = default_timer()

featuresdf_10_test_13=extract_features_test_emovo()

featuresdf_10_train_13=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 11.672199736666666

# %%
inicio = default_timer()

featuresdf_20_test_13=extract_features_test_emovo()

featuresdf_20_train_13=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 6.904140055000001

# %%
inicio = default_timer()

featuresdf_30_test_13=extract_features_test_emovo()

featuresdf_30_train_13=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 5.8224640916666655

# %%
inicio = default_timer()

featuresdf_40_test_13=extract_features_test_emovo()

featuresdf_40_train_13=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 4.460123501666669

# %%
inicio = default_timer()

featuresdf_50_test_13=extract_features_test_emovo()

featuresdf_50_train_13=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 4.467880176666665

# %%
inicio = default_timer()

featuresdf_60_test_13=extract_features_test_emovo()

featuresdf_60_train_13=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 4.998781755

# %%
inicio = default_timer()

featuresdf_70_test_13=extract_features_test_emovo()

featuresdf_70_train_13=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 5.896019861666665

# %%
inicio = default_timer()

featuresdf_80_test_13=extract_features_test_emovo()

featuresdf_80_train_13=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 5.859224308333334

# %%
inicio = default_timer()

featuresdf_90_test_13=extract_features_test_emovo()

featuresdf_90_train_13=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 7.165339696666661

# %%
inicio = default_timer()

featuresdf_100_test_13=extract_features_test_emovo()

featuresdf_100_train_13=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 8.736664213333333

# %%
#%store featuresdf_10_test_13
#%store featuresdf_10_train_13
#%store featuresdf_20_test_13
#%store featuresdf_20_train_13
# %store featuresdf_30_test_13
# %store featuresdf_30_train_13
# %store featuresdf_40_test_13
# %store featuresdf_40_train_13
# %store featuresdf_50_test_13
# %store featuresdf_50_train_13
# %store featuresdf_60_test_13
# %store featuresdf_60_train_13
# %store featuresdf_70_test_13
# %store featuresdf_70_train_13
# %store featuresdf_80_test_13
# %store featuresdf_80_train_13
# %store featuresdf_90_test_13
# %store featuresdf_90_train_13
# %store featuresdf_100_test_13
# %store featuresdf_100_train_13
# Out:
# Stored 'featuresdf_30_test_13' (DataFrame)
# Stored 'featuresdf_30_train_13' (DataFrame)
# Stored 'featuresdf_40_test_13' (DataFrame)
# Stored 'featuresdf_40_train_13' (DataFrame)
# Stored 'featuresdf_50_test_13' (DataFrame)
# Stored 'featuresdf_50_train_13' (DataFrame)
# Stored 'featuresdf_60_test_13' (DataFrame)
# Stored 'featuresdf_60_train_13' (DataFrame)
# Stored 'featuresdf_70_test_13' (DataFrame)
# Stored 'featuresdf_70_train_13' (DataFrame)
# Stored 'featuresdf_80_test_13' (DataFrame)
# Stored 'featuresdf_80_train_13' (DataFrame)
# Stored 'featuresdf_90_test_13' (DataFrame)
# Stored 'featuresdf_90_train_13' (DataFrame)
# Stored 'featuresdf_100_test_13' (DataFrame)
# Stored 'featuresdf_100_train_13' (DataFrame)

# %% [markdown]
# ## RASTA-MFCC

# %%
inicio = default_timer()

featuresdf_10_test_14=extract_features_test_emovo()

featuresdf_10_train_14=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 14.175880216666656

# %%
inicio = default_timer()

featuresdf_20_test_14=extract_features_test_emovo()

featuresdf_20_train_14=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 8.244113526666675

# %%
inicio = default_timer()

featuresdf_30_test_14=extract_features_test_emovo()

featuresdf_30_train_14=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 7.115548341666666

# %%
inicio = default_timer()

featuresdf_40_test_14=extract_features_test_emovo()

featuresdf_40_train_14=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 6.267973791666664

# %%
inicio = default_timer()

featuresdf_50_test_14=extract_features_test_emovo()

featuresdf_50_train_14=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 11.671790969999984

# %%
inicio = default_timer()

featuresdf_60_test_14=extract_features_test_emovo()

featuresdf_60_train_14=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 6.499357918333332

# %%
inicio = default_timer()

featuresdf_70_test_14=extract_features_test_emovo()

featuresdf_70_train_14=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 6.606607728333332

# %%
inicio = default_timer()

featuresdf_80_test_14=extract_features_test_emovo()

featuresdf_80_train_14=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 6.737019465000003

# %%
inicio = default_timer()

featuresdf_90_test_14=extract_features_test_emovo()

featuresdf_90_train_14=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 9.27237006833334

# %%
inicio = default_timer()

featuresdf_100_test_14=extract_features_test_emovo()

featuresdf_100_train_14=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 10.191922040000009

# %%
#%store featuresdf_10_test_14
#%store featuresdf_10_train_14
#%store featuresdf_20_test_14
#%store featuresdf_20_train_14
#%store featuresdf_30_test_14
#%store featuresdf_30_train_14
# %store featuresdf_40_test_14
# %store featuresdf_40_train_14
#%store featuresdf_50_test_14
#%store featuresdf_50_train_14
# %store featuresdf_60_test_14
# %store featuresdf_60_train_14
# %store featuresdf_70_test_14
# %store featuresdf_70_train_14
# %store featuresdf_80_test_14
# %store featuresdf_80_train_14
# %store featuresdf_90_test_14
# %store featuresdf_90_train_14
# %store featuresdf_100_test_14
# %store featuresdf_100_train_14
# Out:
# Stored 'featuresdf_40_test_14' (DataFrame)
# Stored 'featuresdf_40_train_14' (DataFrame)
# Stored 'featuresdf_60_test_14' (DataFrame)
# Stored 'featuresdf_60_train_14' (DataFrame)
# Stored 'featuresdf_70_test_14' (DataFrame)
# Stored 'featuresdf_70_train_14' (DataFrame)
# Stored 'featuresdf_80_test_14' (DataFrame)
# Stored 'featuresdf_80_train_14' (DataFrame)
# Stored 'featuresdf_90_test_14' (DataFrame)
# Stored 'featuresdf_90_train_14' (DataFrame)
# Stored 'featuresdf_100_test_14' (DataFrame)
# Stored 'featuresdf_100_train_14' (DataFrame)

# %%
inicio = default_timer()

featuresdf_10_test_15=extract_features_test_emovo()

featuresdf_10_train_15=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 10.938321923333326

# %%
inicio = default_timer()

featuresdf_20_test_15=extract_features_test_emovo()

featuresdf_20_train_15=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 6.882078126666662

# %%
inicio = default_timer()

featuresdf_30_test_15=extract_features_test_emovo()

featuresdf_30_train_15=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 6.129068615000021

# %%
inicio = default_timer()

featuresdf_40_test_15=extract_features_test_emovo()

featuresdf_40_train_15=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 5.7303037766666725

# %%
inicio = default_timer()

featuresdf_50_test_15=extract_features_test_emovo()

featuresdf_50_train_15=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 5.985337004999989

# %%
inicio = default_timer()

featuresdf_60_test_15=extract_features_test_emovo()

featuresdf_60_train_15=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 6.1879976033333755

# %%
inicio = default_timer()

featuresdf_70_test_15=extract_features_test_emovo()

featuresdf_70_train_15=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 7.209308503333341

# %%
inicio = default_timer()

featuresdf_80_test_15=extract_features_test_emovo()

featuresdf_80_train_15=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 7.254617680000047

# %%
inicio = default_timer()

featuresdf_90_test_15=extract_features_test_emovo()

featuresdf_90_train_15=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 8.824786161666633

# %%
inicio = default_timer()

featuresdf_100_test_15=extract_features_test_emovo()

featuresdf_100_train_15=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 9.400133548333299

# %%
# %store featuresdf_10_test_15
# %store featuresdf_10_train_15
# %store featuresdf_20_test_15
# %store featuresdf_20_train_15
# %store featuresdf_30_test_15
# %store featuresdf_30_train_15
# %store featuresdf_40_test_15
# %store featuresdf_40_train_15
# %store featuresdf_50_test_15
# %store featuresdf_50_train_15
# %store featuresdf_60_test_15
# %store featuresdf_60_train_15
# %store featuresdf_70_test_15
# %store featuresdf_70_train_15
# %store featuresdf_80_test_15
# %store featuresdf_80_train_15
# %store featuresdf_90_test_15
# %store featuresdf_90_train_15
# %store featuresdf_100_test_15
# %store featuresdf_100_train_15
# Out:
# Stored 'featuresdf_10_test_15' (DataFrame)
# Stored 'featuresdf_10_train_15' (DataFrame)
# Stored 'featuresdf_20_test_15' (DataFrame)
# Stored 'featuresdf_20_train_15' (DataFrame)
# Stored 'featuresdf_30_test_15' (DataFrame)
# Stored 'featuresdf_30_train_15' (DataFrame)
# Stored 'featuresdf_40_test_15' (DataFrame)
# Stored 'featuresdf_40_train_15' (DataFrame)
# Stored 'featuresdf_50_test_15' (DataFrame)
# Stored 'featuresdf_50_train_15' (DataFrame)
# Stored 'featuresdf_60_test_15' (DataFrame)
# Stored 'featuresdf_60_train_15' (DataFrame)
# Stored 'featuresdf_70_test_15' (DataFrame)
# Stored 'featuresdf_70_train_15' (DataFrame)
# Stored 'featuresdf_80_test_15' (DataFrame)
# Stored 'featuresdf_80_train_15' (DataFrame)
# Stored 'featuresdf_90_test_15' (DataFrame)
# Stored 'featuresdf_90_train_15' (DataFrame)
# Stored 'featuresdf_100_test_15' (DataFrame)
# Stored 'featuresdf_100_train_15' (DataFrame)

# %%
inicio = default_timer()

featuresdf_10_test_16=extract_features_test_emovo()

featuresdf_10_train_16=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 13.190168773333365

# %%
inicio = default_timer()

featuresdf_20_test_16=extract_features_test_emovo()

featuresdf_20_train_16=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 8.814469370000007

# %%
inicio = default_timer()

featuresdf_30_test_16=extract_features_test_emovo()

featuresdf_30_train_16=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 7.551871978333293

# %%
inicio = default_timer()

featuresdf_40_test_16=extract_features_test_emovo()

featuresdf_40_train_16=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 8.476480493333293

# %%
inicio = default_timer()

featuresdf_50_test_16=extract_features_test_emovo()

featuresdf_50_train_16=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 8.956724576666723

# %%
inicio = default_timer()

featuresdf_60_test_16=extract_features_test_emovo()

featuresdf_60_train_16=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 7.244999925000017

# %%
inicio = default_timer()

featuresdf_70_test_16=extract_features_test_emovo()

featuresdf_70_train_16=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 7.535842330000014

# %%
inicio = default_timer()

featuresdf_80_test_16=extract_features_test_emovo()

featuresdf_80_train_16=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 8.002382045000013

# %%
inicio = default_timer()

featuresdf_90_test_16=extract_features_test_emovo()

featuresdf_90_train_16=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 10.05697370333334

# %%
inicio = default_timer()

featuresdf_100_test_16=extract_features_test_emovo()

featuresdf_100_train_16=extract_features_train_emovo()

fin = default_timer()
print((fin - inicio)/60)
# Out:
# Finished feature extraction from  175  files
# Finished feature extraction from  413  files
# 11.175137231666668

# %%
#%store featuresdf_10_test_16
#%store featuresdf_10_train_16
#%store featuresdf_20_test_16
#%store featuresdf_20_train_16
#%store featuresdf_30_test_16
#%store featuresdf_30_train_16
#%store featuresdf_40_test_16
#%store featuresdf_40_train_16
#%store featuresdf_50_test_16
#%store featuresdf_50_train_16
# %store featuresdf_60_test_16
# %store featuresdf_60_train_16
# %store featuresdf_70_test_16
# %store featuresdf_70_train_16
# %store featuresdf_80_test_16
# %store featuresdf_80_train_16
# %store featuresdf_90_test_16
# %store featuresdf_90_train_16
# %store featuresdf_100_test_16
# %store featuresdf_100_train_16
# Out:
# Stored 'featuresdf_60_test_16' (DataFrame)
# Stored 'featuresdf_60_train_16' (DataFrame)
# Stored 'featuresdf_70_test_16' (DataFrame)
# Stored 'featuresdf_70_train_16' (DataFrame)
# Stored 'featuresdf_80_test_16' (DataFrame)
# Stored 'featuresdf_80_train_16' (DataFrame)
# Stored 'featuresdf_90_test_16' (DataFrame)
# Stored 'featuresdf_90_train_16' (DataFrame)
# Stored 'featuresdf_100_test_16' (DataFrame)
# Stored 'featuresdf_100_train_16' (DataFrame)

# %%
class mel_freq_ceps_coef:
    def __init__(self,file_name,volumen,volumen2):
        try:    
            #Lee archivo de audio
            #self.signal, self.fs = librosa.load(file_name)
            self.fs, self.signal = rd.read(file_name)
            self.signal = volumen * self.signal
            self.volumen2 = volumen2
            #Frecuencia máxima
            self.f_max = self.fs/2.0
            #Constante de preénfasis
            self.preemphasis = 0.97
            #Tamaño de frame en segundos
            self.frame=0.03
            #Porcentaje de traslape
            self.overlap = 50        
            #Tipo de ventana
            self.window = 2
            #Frecuencia mínima
            self.f_min = 0
            #número de filtros en el banco
            self.n_filters = 22#escala de bark 22.05KHz
            #Número de coeficientes mfcc
            self.n_mfcc = 24
            #Normalización
            self.norm = 1
            #RASTA análisis
            self.rasta = 0
            self.audio = self.signal/32767
            self.audio_length = len(self.signal)
            self.frame_size = np.fix(self.frame*self.fs)
            self.overlap_size = np.fix(self.frame_size - self.frame_size*(self.overlap/100.0))
            self.n_frames = self.__Frames()
            self.audio_avg = self.__Stereo()
            self.half_n = np.fix(self.frame_size/2.0)
            self.window_data = self.__Window()
            self.freqs = self.__Freqs()
            self.mel_freqs = self.__Mel_Freqs()
            self.mel_filter_bank = self.__Mel_Filter()
            self.coef, self.nl = self.__MFCC_Coef()
            self.coef = self.coef[:,0:self.nl]
            self.mfccsscalade = np.mean(self.coef.T, axis=0)
        except Exception as e:
            print("Error encoutered while parsing file: ", file_name)
            return None
        #np.savetxt("A51.txt", np.column_stack(self.coef[:,0:self.nl]),  delimiter=",", fmt="%f")
#np.savetxt('myfile.txt', np.c_[x,y,z])     
    #Convierte señales estereofónicas a monoaurales
    def __Stereo(self):
        n_channel = len(np.shape(self.audio))
        if n_channel > 1:
            temp_1 = self.audio[:,0]
            temp_2 = self.audio[:,1]
            avg = (temp_1 + temp_2)/2
        else:
            avg = self.audio
       
        #Aplica filtro de preénfasis
        if self.preemphasis != 0.0:
            Avg = np.zeros(len(avg))    
            Avg[0] = avg[0]
            for n in range(1,len(avg)):
                Avg[n] = avg[n] - self.preemphasis*avg[n-1]            
            return Avg*self.volumen2
        else:
            return avg
            
    #Determina número de frames para analizar
    def __Frames(self):
        i = 0
        j = 0
        while(j < self.audio_length):
            j = i*self.overlap_size + self.frame_size
            i = i + 1
        return i - 1
    
    #Aplica ventana (Hann, Hamming, Box) a frame de la señal
    def __Window(self):
        n = np.arange(-self.half_n,self.half_n)
        if len(n) != self.frame_size:
            n = np.arange(-self.half_n,self.half_n+1)
        
        #Ventana Box
        if self.window == 0:
            W = np.ones(len(n))
        
        #Ventana Hamming
        if self.window == 1:
            a = 0.53836
            b = 0.46164
            W = np.array([])
            for i in n:
                W =np.append(W, a + b*math.cos((2*math.pi*i)/(self.frame_size - 1.0))) 
        
        #Ventana Hann
        if self.window == 2:
            a = 0.5
            b = 0.5
            W = np.array([])
            for i in n:
                W = np.append(W, a + b*math.cos((2*math.pi*i)/(self.frame_size - 1.0)))        
        return W
    
    #Calcula frecuencias en Hertz
    def __Freqs(self):
        n = np.arange(0,self.half_n)
        f = np.array([])
        for i in n:
            f = np.append(f,(i*self.fs)/self.frame_size)
        return f
    
    #Calcula frecuencias en escala de Mel
    def __Mel_Freqs(self):
        n = np.arange(0,self.half_n)
        f = np.array([])
        for i in n:
            f = np.append(f,2595*np.log10(self.freqs[int(i)]/700+1))
        return f
    
    #Genera banco de filtros triangulares 
    def __Mel_Filter(self):
        try:
            phi_min = 2595*math.log10(self.f_min/700+1)
            phi_max = 2595*math.log10(self.f_max/700+1)
            dphi = (phi_max - phi_min)/(self.n_filters+1)
            fc = np.zeros(self.n_filters+2)
            fc[0] = self.f_min
            for i in range(1,len(fc)):
                phic = (i-1)*dphi
                fc[i-1] = 700*(math.pow(10,(phic + phi_min)/2595)-1)
            fc[self.n_filters+1] = self.f_max
            Hkm = np.zeros((int(self.half_n),self.n_filters))
            n = np.arange(0,self.half_n)
            for i in range(1,self.n_filters+1):
                for k in n:
                    kk = int(k)
                    if self.freqs[kk] < fc[i-1]:
                        Hkm[kk,i-1] = 0
                    if (self.freqs[kk] >= fc[i-1]) and (self.freqs[kk] < fc[i]):
                        Hkm[kk,i-1] = (self.freqs[kk] - fc[i-1])/(fc[i] - fc[i-1])
                    if (self.freqs[kk] >= fc[i]) and (self.freqs[kk] < fc[i+1]):
                        Hkm[kk,i-1] = (self.freqs[kk] - fc[i+1])/(fc[i] - fc[i+1])
                    if self.freqs[kk] >= fc[i+1]:
                        Hkm[kk,i-1] = 0
            return Hkm
        except Exception as e:
            print("Error encoutered while parsing file: ", file_name)
            return None    
    #Determina coeficientes cepstrales de frecuencia de mel    
    def __MFCC_Coef(self):
        try:
            frame = np.zeros(int(self.frame_size))
            self.energy = np.zeros((int(self.half_n),self.n_frames))
            self.cepstrum = np.zeros((self.n_filters,self.n_frames))
            Xm = np.zeros(self.n_filters)
            mfcc = np.zeros(self.n_mfcc) 
            wi = np.zeros(2*self.n_mfcc)
            MFCC = np.zeros((self.n_mfcc,self.n_frames))

            #Pesos para el proceso de liftering
            for i in range(0,2*self.n_mfcc):
                wi[i] = 1 + self.n_mfcc*np.sin(math.pi*i/(2*self.n_mfcc-1))

            #Coeficientes del filtro RASTA
            numer = np.arange(-2,3)
            numer = -numer/np.sum(numer*numer)
            denom = np.array([1,-0.98])

            l = 0
            #Análisis de frames
            for i in range(0,int(self.n_frames)):
                #Extrae frame de la señal
                frame = self.audio_avg[i*int(self.overlap_size):i*int(self.overlap_size)+int(self.frame_size)]

                #función de autocorrelación
                acorr = np.correlate(frame,frame,mode='full')
                m = np.amax(acorr[20:len(acorr)])

                #if m > 0.1:
                if np.sum(frame)!=0:

                    #Multiplica frame por ventana
                    frame = frame*self.window_data
                    #Extrae espectro de potencia 
                    P = np.abs(fourier.fft(frame))
                    #Determina espectrograma de la señal
                    self.energy[:,l] = 10*np.log10(P[0:int(self.half_n)]) 

                    for j in range(0,self.n_filters):
                        #Multiplica espectro de potencia por filtros triangulares
                        Ps = P[0:int(self.half_n)]*self.mel_filter_bank[:,j]
                        #Aplica el proceso RASTA a cada banda de frecuencia
                        if self.rasta == 1:
                            Ps = np.log(1+Ps)
                            Ps = sg.lfilter(numer,denom, Ps)
                            Ps = np.exp(Ps)-1
                        Xm[j] = np.log(np.sum(Ps))
                    #Determina cepstrum de la señal
                    self.cepstrum[:,l] = Xm

                    #Aplica transformada coseno
                    for j in range(1,self.n_mfcc+1):
                        suma = 0
                        for k in range(1,self.n_filters+1):
                            suma = suma + Xm[k-1]*np.cos(math.pi*j*(k-(1/2))/self.n_filters)
                        mfcc[j-1] = suma 
                    #Aplica proceso de liftering
                    mfcc = mfcc*wi[0:self.n_mfcc]
                    #Genera matriz de coeficientes mfcc
                    MFCC[:,l] = mfcc
                    l = l + 1


            #Normaliza matriz de coeficientes mfcc
            if self.norm == 1:
                '''
                for i in range(0,self.n_mfcc):
                    MFCC[i,:] = (MFCC[i,:]-np.mean(MFCC[i,:]))/np.std(MFCC[i,:]) 
                '''
                MFCC = (MFCC-np.mean(MFCC))/np.std(MFCC)
                
            return MFCC, l
        except Exception as e:
            print("Error encoutered while parsing file: ", file_name)
            return None

# %%
def extract_features_test_emovo():
    
    try:
        fulldatasetpath = r'C:\Users\SACKRAY7\Desktop\Uni\8vo\TESIS\retomando la tesis 23-06-2020\Udacity-ML-Capstone-master\Udacity-ML-Capstone-master\emovo - testSize 0.3\audio'

        metadata = pd.read_csv(r'C:\Users\SACKRAY7\Desktop\Uni\8vo\TESIS\retomando la tesis 23-06-2020\Udacity-ML-Capstone-master\Udacity-ML-Capstone-master\UrbanSound Dataset sample\metadata\emovo2 - testSize 0.3.csv')

        features_emovo = []

        # Iterate through each sound file and extract the features 
        for index, row in metadata.iterrows():

            file_name = os.path.join(os.path.abspath(fulldatasetpath),str(row["fold"])+'/',str(row["slice_file_name"]))

            class_label = row["class_name"]
            volumen = row["volumen"]
            volumen2 = row["volumen2"]
            if row["if"] == "test": 
                data = mel_freq_ceps_coef(file_name, volumen, volumen2)
                features_emovo.append([data.mfccsscalade, class_label])
                #plt.figure(i)
                #plt.title(file_name)
                #espectrogram = data.energy
                #plt.imshow(espectrogram[::-1],cmap=plt.get_cmap('jet'),extent = [0,data.n_frames,f_min,f_max],aspect="auto")
            

        # Convert into a Panda dataframe 
        featuresdf_emovo = pd.DataFrame(features_emovo, columns=['feature','class_label'])

        print('Finished feature extraction from ', len(featuresdf_emovo), ' files') 

    except Exception as e:
        print("Error encoutered while parsing file: ", file_name)
        return None

    return featuresdf_emovo

# %%
def extract_features_train_emovo():
    
    try:
        fulldatasetpath = r'C:\Users\SACKRAY7\Desktop\Uni\8vo\TESIS\retomando la tesis 23-06-2020\Udacity-ML-Capstone-master\Udacity-ML-Capstone-master\emovo - testSize 0.3\audio'

        metadata = pd.read_csv(r'C:\Users\SACKRAY7\Desktop\Uni\8vo\TESIS\retomando la tesis 23-06-2020\Udacity-ML-Capstone-master\Udacity-ML-Capstone-master\UrbanSound Dataset sample\metadata\emovo2 - testSize 0.3.csv')

        features_emovo = []

        # Iterate through each sound file and extract the features 
        for index, row in metadata.iterrows():

            file_name = os.path.join(os.path.abspath(fulldatasetpath),str(row["fold"])+'/',str(row["slice_file_name"]))

            class_label = row["class_name"]
            volumen = row["volumen"]
            volumen2 = row["volumen2"]
            if row["if"] == "train": 
                data = mel_freq_ceps_coef(file_name, volumen, volumen2)
                features_emovo.append([data.mfccsscalade, class_label])

        # Convert into a Panda dataframe 
        featuresdf_emovo = pd.DataFrame(features_emovo, columns=['feature','class_label'])

        print('Finished feature extraction from ', len(featuresdf_emovo), ' files') 

    except Exception as e:
        print("Error encoutered while parsing file: ", file_name)
        return None

    return featuresdf_emovo

# %%
import matplotlib.pyplot as plt
import scipy.io.wavfile as rd
import scipy.fftpack as fourier
import scipy.signal as sg
import numpy as np
import math 

import pandas as pd
import os
import librosa
from timeit import default_timer
