# %%
import pandas as pd
import numpy as np

from sklearn.svm import SVC
#from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from sklearn.preprocessing import LabelEncoder

# %%
# %store -r featuresdf_test_EMODB
# %store -r featuresdf_train_EMODB
# Out:
# no stored variable or alias featuresdf_test_EMODB
# no stored variable or alias featuresdf_train_EMODB

# %%
X_test = np.array(featuresdf_test_EMODB.feature.tolist())
y_test = np.array(featuresdf_test_EMODB.class_label.tolist())

le = LabelEncoder()
y_test = le.fit_transform(y_test)

X_train = np.array(featuresdf_train_EMODB.feature.tolist())
y_train = np.array(featuresdf_train_EMODB.class_label.tolist())

y_train = le.fit_transform(y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20122/1900009590.py in <cell line: 1>()
# ----> 1 X_test = np.array(featuresdf_test_EMODB.feature.tolist())
#       2 y_test = np.array(featuresdf_test_EMODB.class_label.tolist())
#       3
#       4 le = LabelEncoder()
#       5 y_test = le.fit_transform(y_test)
#
# NameError: name 'featuresdf_test_EMODB' is not defined

# %%
# %store -r  featuresdf_test_emovo
# %store -r  featuresdf_train_emovo
# Out:
# no stored variable or alias featuresdf_test_emovo
# no stored variable or alias featuresdf_train_emovo

# %%
# Convert features and corresponding classification labels into numpy arrays
X_test = np.array(featuresdf_test_emovo.feature.tolist())
y_test = np.array(featuresdf_test_emovo.class_label.tolist())

le = LabelEncoder()
y_test = le.fit_transform(y_test)

X_train = np.array(featuresdf_train_emovo.feature.tolist())
y_train = np.array(featuresdf_train_emovo.class_label.tolist())

y_train = le.fit_transform(y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20122/1785825928.py in <cell line: 2>()
#       1 # Convert features and corresponding classification labels into numpy arrays
# ----> 2 X_test = np.array(featuresdf_test_emovo.feature.tolist())
#       3 y_test = np.array(featuresdf_test_emovo.class_label.tolist())
#       4
#       5 le = LabelEncoder()
#
# NameError: name 'featuresdf_test_emovo' is not defined

# %%
"""
#usar con "from sklearn.svm import LinearSVC" descomentando arriba
#svclassifier = LinearSVC(random_state=0, tol=1e-5,multi_class='crammer_singer',max_iter=100000,dual = True)
"""

#svclassifier = SVC(kernel='poly', degree=3)
#svclassifier = SVC(kernel='sigmoid')
#svclassifier = SVC(kernel='precomputed')
#svclassifier = SVC(kernel='rbf')
#svclassifier = SVC(kernel='linear')


for kernel in ('linear', 'rbf', 'poly', 'sigmoid'):
    svclassifier = SVC(kernel=kernel, gamma=1, degree=3)
    svclassifier.fit(X_train, y_train)
    print('{:.2f}'.format(svclassifier.score(X_test,y_test)),'(',kernel,')')
    
for kernel in ('linear', 'rbf', 'poly', 'sigmoid'):
    svclassifier = SVC(kernel=kernel, gamma=1, degree=3)
    svclassifier.fit(X_train, y_train)
    print(kernel)
    print('Accuracy of SVM classifier on training set : {:.2f}'.format(svclassifier.score(X_train,y_train)))
    print('Accuracy of SVM classifier on test set : {:.2f}'.format(svclassifier.score(X_test,y_test)))
    pred = svclassifier.predict(X_test)
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20122/418956786.py in <cell line: 13>()
#      13 for kernel in ('linear', 'rbf', 'poly', 'sigmoid'):
#      14     svclassifier = SVC(kernel=kernel, gamma=1, degree=3)
# ---> 15     svclassifier.fit(X_train, y_train)
#      16     print('{:.2f}'.format(svclassifier.score(X_test,y_test)),'(',kernel,')')
#      17
#
# NameError: name 'X_train' is not defined

# %%
# %store -r featuresdf_EMODB

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split 

# Convert features and corresponding classification labels into numpy arrays
X = np.array(featuresdf_EMODB.feature.tolist())
y = np.array(featuresdf_EMODB.class_label.tolist())

# Encode the classification labels
le = LabelEncoder()
yy = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, yy, test_size=0.3, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20122/849143790.py in <cell line: 6>()
#       4
#       5 # Convert features and corresponding classification labels into numpy arrays
# ----> 6 X = np.array(featuresdf_EMODB.feature.tolist())
#       7 y = np.array(featuresdf_EMODB.class_label.tolist())
#       8
#
# NameError: name 'featuresdf_EMODB' is not defined

# %%
# %store -r  featuresdf_emovo
# Out:
# no stored variable or alias featuresdf_emovo

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split 

# Convert features and corresponding classification labels into numpy arrays
X = np.array(featuresdf_emovo.feature.tolist())
y = np.array(featuresdf_emovo.class_label.tolist())

# Encode the classification labels
le = LabelEncoder()
yy = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, yy, test_size=0.4, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20122/568399406.py in <cell line: 6>()
#       4
#       5 # Convert features and corresponding classification labels into numpy arrays
# ----> 6 X = np.array(featuresdf_emovo.feature.tolist())
#       7 y = np.array(featuresdf_emovo.class_label.tolist())
#       8
#
# NameError: name 'featuresdf_emovo' is not defined

# %%
print(X_train)
print(X_test)
print(y_train)
print(y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20122/1433298227.py in <cell line: 1>()
# ----> 1 print(X_train)
#       2 print(X_test)
#       3 print(y_train)
#       4 print(y_test)
#
# NameError: name 'X_train' is not defined
